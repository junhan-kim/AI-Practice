# %% [markdown]
# ## textbook 117.p  Q) 3.19
#
# ### Q. Write a program that will take as input two Web page URLs and find a path of links from one to the other

# %% [markdown]
# ## [Restrictions]
# ### It can only move between directories within a specific site (MSA is not applied)
#
# ## [Test cases]
# ### https://stackoverflow.com    https://stackoverflow.com/teams/use-cases
# ### https://github.com                 https://github.com/collections/pixel-art-tools
# ### https://stackexchange.com  https://stackexchange.com/about/security

# %%
import argparse
import sys
from bs4 import BeautifulSoup
import requests
import requests.exceptions
from urllib.parse import urlsplit
from urllib.parse import urlparse
from collections import deque
from heapq import heappush, heappop
from queue import PriorityQueue
from difflib import SequenceMatcher

# %%
src = "https://github.com"   # src must be ancestor website of dest, but no matter during tracing
dest = "https://github.com/collections/pixel-art-tools"

# %%
protocols = (
    "https://",
    "http://"
)

top_level_domains = (
    ".com",
    ".org",
    ".net",
    ".edu",
    ".gov",
)

# %%
# Validation for top level domain
for domain in top_level_domains:
    if not src.find(domain) == -1:
        src_top_level_domain = domain
        if not dest.find(domain) == -1:
            dest_top_level_domain = domain
        break
        
# Validation for protocol
for protocol in protocols:
    if not src.find(protocol) == -1:
        src_protocol = protocol
        if not dest.find(protocol) == -1:
            dest_protocol = protocol

# Get src and dest domain
src_split = src.split('.', 3)
if src_split[1] == src_top_level_domain.split('.')[1]:
    domain = src_split[0].split(src_protocol, 1)[1]
    subdomain = ''
elif src_split[2] == src_top_level_domain.split('.')[1]:
    domain = src_split[1]
    subdomain = src_split[0]

# %%
print('domain : ' + domain)
print('src_top_level_domain : ' + src_top_level_domain + '\n')
print('src : ' + src)
print('dest : ' + dest)
print('==================================')
# Out:
# domain : github
# src_top_level_domain : .com
#
# src : https://github.com
# dest : https://github.com/collections/pixel-art-tools
# ==================================

# %%
def get_heuristic(local_url):
  string_match_ratio = SequenceMatcher(None, local_url, dest).ratio()  # Matching ratio between two strings
  return (1 - string_match_ratio)   # Subtract from 1 because it is heuristic value

def get_neighbor(cur):
  response = requests.get(cur)  # request for response from current website
  soup = BeautifulSoup(response.text, "lxml")
  ret = []
  for link in soup.find_all('a'):
    # anchor is the value corresponding to each <a href> tag  (That is, all links that can be moved from the current website)
    anchor = link.attrs["href"] if "href" in link.attrs else ''
    if ((protocols[0] in anchor) or (protocols[1] in anchor)):  # http or https protocol
      if (((anchor.split('/'))[2]).split('.')[0] == domain): # Move only within the current domain
        ret.append(anchor)
    else:  # If the link is a relative path, not a full name
      ret.append(src + anchor)
  return ret

# %%
def greedy_search(start, goal):
  fringe = PriorityQueue()  # use priority queue
  fringe.put((0, start))
  came_from = {} 
  came_from[start] = None
  
  while not fringe.empty():
    current = fringe.get()[1]  # get the link with the minimum heuristic value 
    if current == goal:
      break
    print('cur : ' + current) 
    print('==================================')
    for next in get_neighbor(current):
      if next not in came_from:
        print('next : ' + next)
        priority = get_heuristic(next)
        print('heuristic value : ' + str(get_heuristic(next)))
        fringe.put((priority, next))  # set priority with link name
        came_from[next] = current  # set parent link
    print('\n')
  return came_from

# %%
came_from = greedy_search(src, dest)
print('Reached the goal')
print('\n')
print('=== Website stack trace ===')
cur = dest
while not (cur == None):  # print stack trace
  print(cur)
  cur = came_from[cur]
# Out:
# cur : https://github.com
# ==================================
# next : https://github.com#start-of-content
# heuristic value : 0.3827160493827161
# next : https://github.com/
# heuristic value : 0.41538461538461535
# next : https://github.com/join?source=header-home
# heuristic value : 0.43181818181818177
# next : https://github.com/features
# heuristic value : 0.36986301369863017
# next : https://github.com/features/code-review/
# heuristic value : 0.4418604651162791
# next : https://github.com/features/project-management/
# heuristic value : 0.3978494623655914
# next : https://github.com/features/integrations
# heuristic value : 0.41860465116279066
# next : https://github.com/features/actions
# heuristic value : 0.3580246913580247
# next : https://github.com/features/packages
# heuristic value : 0.36585365853658536
# next : https://github.com/features/security
# heuristic value : 0.41463414634146345
# next : https://github.com/features#team-management
# heuristic value : 0.4831460674157303
# next : https://github.com/features#hosting
# heuristic value : 0.4320987654320988
# next : https://github.com/customer-stories
# heuristic value : 0.40740740740740744
# next : https://github.com/security
# heuristic value : 0.36986301369863017
# next : https://github.com/team
# heuristic value : 0.3623188405797102
# next : https://github.com/enterprise
# heuristic value : 0.3866666666666667
# next : https://github.com/explore
# heuristic value : 0.36111111111111116
# next : https://github.com/topics
# heuristic value : 0.3802816901408451
# next : https://github.com/collections
# heuristic value : 0.21052631578947367
# next : https://github.com/trending
# heuristic value : 0.4246575342465754
# next : https://github.com/events
# heuristic value : 0.352112676056338
# next : https://github.community
# heuristic value : 0.4
# next : https://github.com/marketplace
# heuristic value : 0.39473684210526316
# next : https://github.com/pricing
# heuristic value : 0.41666666666666663
# next : https://github.com/pricing#feature-comparison
# heuristic value : 0.4505494505494505
# next : https://github.com/nonprofit
# heuristic value : 0.3513513513513513
# next : https://github.com/login
# heuristic value : 0.37142857142857144
# next : https://github.com/open-source
# heuristic value : 0.368421052631579
# next : https://github.com/business
# heuristic value : 0.36986301369863017
# next : https://github.com/join?source=button-home
# heuristic value : 0.36363636363636365
# next : https://github.com/join?plan=free&source=pricing-card-free
# heuristic value : 0.46153846153846156
# next : https://github.com/join?plan=business&setup_organization=true&source=home
# heuristic value : 0.5294117647058824
# next : https://github.com/features/code-review
# heuristic value : 0.43529411764705883
# next : https://github.com/features/project-management
# heuristic value : 0.3913043478260869
# next : https://github.com/customer-stories/mgm-resorts
# heuristic value : 0.4838709677419355
# next : https://github.com/customer-stories/nationwide
# heuristic value : 0.3913043478260869
# next : https://github.com/customer-stories/sap
# heuristic value : 0.43529411764705883
# next : https://github.com/customer-stories/spotify
# heuristic value : 0.4606741573033708
# next : https://github.com/customer-stories/freakboy3742
# heuristic value : 0.4893617021276596
# next : https://github.com/customer-stories/kris-nova
# heuristic value : 0.4725274725274725
# next : https://github.com/customer-stories/yyx990803
# heuristic value : 0.4725274725274725
# next : https://github.com/customer-stories/jessfraz
# heuristic value : 0.4666666666666667
# next : https://github.com/personal
# heuristic value : 0.34246575342465757
# next : https://github.com/contact
# heuristic value : 0.36111111111111116
# next : https://github.com/about
# heuristic value : 0.4
# next : https://github.blog
# heuristic value : 0.4769230769230769
# next : https://github.com/about/careers
# heuristic value : 0.3589743589743589
# next : https://github.com/about/press
# heuristic value : 0.3421052631578947
# next : https://github.com/github
# heuristic value : 0.4084507042253521
# next : https://github.com/site/terms
# heuristic value : 0.36
# next : https://github.com/site/privacy
# heuristic value : 0.4025974025974026
#
#
# cur : https://github.com/collections
# ==================================
# next : https://github.com/join?source=header
# heuristic value : 0.42168674698795183
# next : https://github.com/login?return_to=%2Fcollections
# heuristic value : 0.368421052631579
# next : https://github.com/sponsors/community
# heuristic value : 0.42168674698795183
# next : https://github.com/explore/email
# heuristic value : 0.3846153846153846
# next : https://github.com/collections/pixel-art-tools
# heuristic value : 0.0
# next : https://github.com/collections/learn-to-code
# heuristic value : 0.15555555555555556
# next : https://github.com/collections/text-editors
# heuristic value : 0.1685393258426966
# next : https://github.com/collections/choosing-projects
# heuristic value : 0.276595744680851
# next : https://github.com/collections/clean-code-linters
# heuristic value : 0.2210526315789474
# next : https://github.com/collections/open-journalism
# heuristic value : 0.23913043478260865
# next : https://github.com/collections/design-essentials
# heuristic value : 0.23404255319148937
# next : https://github.com/collections/music
# heuristic value : 0.2195121951219512
# next : https://github.com/collections/government
# heuristic value : 0.26436781609195403
# next : https://github.com/collections/devops-tools
# heuristic value : 0.1460674157303371
# next : https://github.com/collections/front-end-javascript-frameworks
# heuristic value : 0.35185185185185186
# next : https://github.com/collections/github-browser-extensions
# heuristic value : 0.2941176470588235
# next : https://github.com/collections/github-pages-examples
# heuristic value : 0.2857142857142857
# next : https://github.com/collections/hacking-minecraft
# heuristic value : 0.276595744680851
# next : https://github.com/collections/javascript-game-engines
# heuristic value : 0.28
# next : https://github.com/collections/machine-learning
# heuristic value : 0.22580645161290325
# next : https://github.com/collections/made-in-africa
# heuristic value : 0.23076923076923073
# next : https://github.com/collections/net-neutrality
# heuristic value : 0.20879120879120883
# next : https://github.com/collections/open-data
# heuristic value : 0.2558139534883721
# next : https://github.com/collections/open-source-organizations
# heuristic value : 0.3529411764705882
# next : https://github.com/collections/policies
# heuristic value : 0.17647058823529416
# next : https://github.com/collections/productivity-tools
# heuristic value : 0.1578947368421053
#
#
# Reached the goal
#
#
# === Website stack trace ===
# https://github.com/collections/pixel-art-tools
# https://github.com/collections
# https://github.com
